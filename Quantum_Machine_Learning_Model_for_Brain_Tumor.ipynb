# %% [markdown]
# <a href="https://colab.research.google.com/github/kylianmbappe9/-Simulating-Quantum-Wavefunction-Dynamics-and-Interference-Patterns/blob/main/Quantum_Machine_Learning_Model_for_Brain_Tumor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import clear_output
# !pip install -q tensorflow

# %%
# !pip install -q tensorflow_quantum

# %%
# !pip install -q qiskit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 6.3 MB/s eta 0:00:00

# %%
# !pip install -q qiskit-aer
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 55.0 MB/s eta 0:00:00

# %%
# !pip install cirq
# Out:
# ...
#   Using cached cirq_core-1.4.1-py3-none-any.whl.metadata (1.8 kB)
# ...
# Using cached cirq_core-1.4.1-py3-none-any.whl (1.9 MB)
# ...
#   Attempting uninstall: cirq-core
#     Found existing installation: cirq-core 1.3.0
#     Uninstalling cirq-core-1.3.0:
#       Successfully uninstalled cirq-core-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-quantum 0.7.3 requires cirq-core==1.3.0, but you have cirq-core 1.4.1 which is incompatible.
# tensorflow-quantum 0.7.3 requires cirq-google==1.3.0, but you have cirq-google 1.4.1 which is incompatible.
# ...

# %%
# !pip install cirq-core

# %%
import numpy as np
import tensorflow as tf
import cirq
import sympy
import qiskit
import tensorflow_quantum as tfq
from cirq.contrib.svg import SVGCircuit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-adde934c688b> in <cell line: 3>()
#       1 import numpy as np
#       2 import tensorflow as tf
# ----> 3 import cirq
#       4 import sympy
#       5 import qiskit
#
# ModuleNotFoundError: No module named 'cirq'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip uninstall -y tensorflow tensorflow-quantum
# Out:
# Found existing installation: tensorflow 2.17.0
# Uninstalling tensorflow-2.17.0:
#   Successfully uninstalled tensorflow-2.17.0
# Found existing installation: tensorflow-quantum 0.7.3
# Uninstalling tensorflow-quantum-0.7.3:
#   Successfully uninstalled tensorflow-quantum-0.7.3

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# ...
# Using cached tensorflow-2.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.3 MB)
# ...

# %%
# !pip install tensorflow-quantum
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 81.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.8/598.8 kB 36.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 78.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# ...

# %%
# !pip install cirq
# Out:
# ...
#   Using cached cirq_core-1.4.1-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached cirq_google-1.4.1-py3-none-any.whl.metadata (2.0 kB)
# ...
# Using cached cirq_core-1.4.1-py3-none-any.whl (1.9 MB)
# Using cached cirq_google-1.4.1-py3-none-any.whl (532 kB)
# ...
#   Attempting uninstall: cirq-core
#     Found existing installation: cirq-core 1.3.0
#     Uninstalling cirq-core-1.3.0:
#       Successfully uninstalled cirq-core-1.3.0
#   Attempting uninstall: cirq-google
#     Found existing installation: cirq-google 1.3.0
#     Uninstalling cirq-google-1.3.0:
#       Successfully uninstalled cirq-google-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-quantum 0.7.3 requires cirq-core==1.3.0, but you have cirq-core 1.4.1 which is incompatible.
# tensorflow-quantum 0.7.3 requires cirq-google==1.3.0, but you have cirq-google 1.4.1 which is incompatible.
# ...

# %%
import tensorflow as tf
import numpy as np
import cirq
import tensorflow_quantum as tfq
from cirq.contrib.svg import SVGCircuit
import sympy
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/tensorflow_quantum/core/ops/load_module.py in load_module(name)
#      41         path = resource_loader.get_path_to_datafile(name)
# ---> 42         return load_library.load_op_library(path)
#      43     except:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/load_library.py in load_op_library(library_filename)
#      53   """
# ---> 54   lib_handle = py_tf.TF_LoadLibrary(library_filename)
#      55   try:
#
# NotFoundError: /usr/local/lib/python3.10/dist-packages/tensorflow_quantum/core/ops/_tfq_simulate_ops.so: undefined symbol: _ZN10tensorflow15OpKernelContext10CtxFailureEPKciRKN4absl12lts_202301256StatusE
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ...

# %%
# !pip install tensorflow_quantum
# Out:
# ...
#   Using cached cirq_core-1.3.0-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached cirq_google-1.3.0-py3-none-any.whl.metadata (2.0 kB)
# ...
# Using cached cirq_core-1.3.0-py3-none-any.whl (1.8 MB)
# Using cached cirq_google-1.3.0-py3-none-any.whl (598 kB)
# ...
#   Attempting uninstall: cirq-core
#     Found existing installation: cirq-core 1.4.1
#     Uninstalling cirq-core-1.4.1:
#       Successfully uninstalled cirq-core-1.4.1
#   Attempting uninstall: cirq-google
#     Found existing installation: cirq-google 1.4.1
#     Uninstalling cirq-google-1.4.1:
#       Successfully uninstalled cirq-google-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cirq 1.4.1 requires cirq-core==1.4.1, but you have cirq-core 1.3.0 which is incompatible.
# cirq 1.4.1 requires cirq-google==1.4.1, but you have cirq-google 1.3.0 which is incompatible.
# ...

# %% [markdown]
# What is UNET
#
# UNET is a deep learning architecture for semantic segmentation

# %% [markdown]
# 3 ways to detect a specific image
#
# 1) classificaiton: this is to judge whether teh image is one thing or another in a broader scale (somewhat like widespread)
# 2) detection: this is to judge an image on a broader LOCALISED region
# 3) segmentation: this is to pinpoiint and easily differentiate whether it is one thing or another on a very closed concentrated region

# %% [markdown]
# Difference between semantic segmentation and instance segmentation
#
# 1) semantic segmentation example
#
# If you have 5 people on a backround image, you will have two common classses, people and backround image (creating number of general classes)
#
# 2) instance segmentation example
#
# If you have 5 people on a backround image, you will have six classes, person 1 - 5 and the backround image. Typicxally, we are having an image and we break them down into several sectors

# %% [markdown]
# UNET architecture is divided into encoder and decoder
#
# encoder goes CONVULATION -> MAXPULL -> CONVULATION -> MAXPULL -> CONVULATION -> MAX PULL
#
# DECODER IS [UP CONVULATION -> CONVULATION -> UP CONVULATION -> CONVULATION -> UP CONVULATION -> CONVULATION]
#
# ![Research.png](data:image/png;base64,...)

# %% [markdown]
# QUANTUM CONVLATIONAL NEURAL NETWORKS
#
# *A Quantum Convolutional Neural Network (QCNN) is a type of neural network that uses quantum computing techniques to analyze data, similar to how classical Convolutional Neural Networks (CNNs) work but with quantum elements.*

# %%
# !pip install pennylane pennylane-qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 34.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 56.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 68.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 60.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.6 MB/s eta 0:00:00
# ...

# %%
# !pip install pillow scikit-image matplotlib

# %% [markdown]
# The method we will be using is something called "Portion by Portion"
#
# 1) The computer system will detect the image [see the image]
# 2) The image that is broken down will be then divided into several sector images
# 3) these several sector images will then be parsed into training data set and testing data set why? bceause these cropped images now undergo either separate segmentation or instance segmentation (depending on how accurate the user want it to be) and all those locally region cropped images will be sent on to testing data set and training data set
#
# THEY DO THE SAME THING FOR OTHER CROPPED IMAGES

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import pennylane as qml
from pennylane import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5f5890a51910> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 import scipy as sp
# ----> 4 import pennylane as qml
#       5 from pennylane import numpy as np
#
# ModuleNotFoundError: No module named 'pennylane'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install pennylane-qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 58.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 74.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 58.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 64.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 50.6 MB/s eta 0:00:00
# ...

# %%
import pennylane as qml
from pennylane import numpy as np

# %%
from PIL import Image
import io
import requests
from skimage import io, color, transform
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# %% [markdown]
# How to import an image using PIL
#
# NOTE: PLEASE USE GOOGLE.COLAB IMPORT FILES WHEN USING A REMOTE ENVIRONMENT

# %%
from PIL import Image
from google.colab import files
import io

uploaded = files.upload()
filename = list(uploaded.keys())[0]
img = Image.open(io.BytesIO(uploaded[filename]))
img.show()
# Out:
#      <input type="file" id="files-b5475b86-b139-4eef-a658-ea2ddc8b4ebc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5475b86-b139-4eef-a658-ea2ddc8b4ebc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Convert the imported image to numpy array

# %%
import numpy as np

img_numpy = np.asarray(img)
print(img_numpy.shape)
print(img_numpy)
# Out:
# (370, 286)
# [[68 32 32 ... 32 32 68]
#  [32  9  7 ...  7  9 32]
#  [43  7  7 ...  7  7 43]
#  ...
#  [33  7  7 ...  7  7 33]
#  [32  7  7 ...  7  7 32]
#  [68 32 32 ... 32 32 68]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import pennylane as qml
from pennylane import numpy as np
from google.colab import files
import matplotlib.image as mpimg

# %%
uploaded = files.upload()
filename = list(uploaded.keys())[0]
img = Image.open(io.BytesIO(uploaded[filename]))
img.show()
# Out:
#      <input type="file" id="files-0ebad1e2-d6b8-4433-b339-96332f78b625" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ebad1e2-d6b8-4433-b339-96332f78b625">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for filename in uploaded.keys():
    img = Image.open(io.BytesIO(uploaded[filename]))
    img.show()
    img_numpy = np.asarray(img)
    print(img_numpy.shape)
    print(img_numpy)
# Out:
# (370, 286)
# [[68 32 32 ... 32 32 68]
#  [32  9  7 ...  7  9 32]
#  [43  7  7 ...  7  7 43]
#  ...
#  [33  7  7 ...  7  7 33]
#  [32  7  7 ...  7  7 32]
#  [68 32 32 ... 32 32 68]]

# %% [markdown]
# How to PHYSICALLY OPEN AN IMAGE USING CV2 MODULE

# %% [markdown]
# GET THE MODULES FIRST

# %%
import numpy as np
from google.colab.patches import cv2_imshow
import cv2
from io import BytesIO

# %%
for filename in uploaded.keys():
  img = Image.open(BytesIO((uploaded[filename])))
  image_cv = np.asarray(img)
  cv2_imshow(image_cv)
  print(image_cv.shape)
  print(image_cv)
# Out:
# <PIL.Image.Image image mode=L size=286x370>
# (370, 286)
# [[68 32 32 ... 32 32 68]
#  [32  9  7 ...  7  9 32]
#  [43  7  7 ...  7  7 43]
#  ...
#  [33  7  7 ...  7  7 33]
#  [32  7  7 ...  7  7 32]
#  [68 32 32 ... 32 32 68]]
